# %% [markdown]
# **Run the following two cells before you begin.**

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.read_csv('D:\Technocolab\Mini Project 2\Task 1\cleaned_data.csv')

# %% [markdown]
# **Run the following 3 cells to create a list of features, create a train/test split, and instantiate a random forest classifier.**

# %%
features_response = df.columns.tolist()
items_to_remove = ['ID', 'SEX', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6',
                   'EDUCATION_CAT', 'graduate school', 'high school', 'none',
                   'others', 'university']
features_response = [item for item in features_response if item not in items_to_remove]
features_response
# Out:
# ['LIMIT_BAL',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_1',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'default payment next month']

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
X_train, X_test, y_train, y_test = train_test_split(
    df[features_response[:-1]].values,
    df['default payment next month'].values,
    test_size=0.2, random_state=24
)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=10, criterion='gini', max_depth=3,
    min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0,
    max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0,
    min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=None,
    random_state=4, verbose=0, warm_start=False, class_weight=None
)

# %% [markdown]
# **Create a dictionary representing the grid for the `max_depth` and `n_estimators` hyperparameters that will be searched. Include depths of 3, 6, 9, and 12, and 10, 50, 100, and 200 trees.**

# %%
params = {'max_depth':[3,6,9,12], 'n_estimators' : [10,50,100,200]}

# %% [markdown]
# ________________________________________________________________
# **Instantiate a `GridSearchCV` object using the same options that we have previously in this course, but with the dictionary of hyperparameters created above. Set `verbose=2` to see the output for each fit performed.**

# %%
from sklearn.model_selection import GridSearchCV
grid_cv = GridSearchCV(rf, param_grid =params, verbose = 2)

# %% [markdown]
# ____________________________________________________
# **Fit the `GridSearchCV` object on the training data.**

# %%
grid_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] max_depth=3, n_estimators=10 ....................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.4s
# [CV] max_depth=3, n_estimators=10 ....................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.3s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.3s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.3s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.3s
# [CV] max_depth=3, n_estimators=50 ....................................
# [CV] ..................... max_depth=3, n_estimators=50, total=   1.5s
# [CV] max_depth=3, n_estimators=50 ....................................
# [CV] ..................... max_depth=3, n_estimators=50, total=   1.6s
# [CV] max_depth=3, n_estimators=50 ....................................
# [CV] ..................... max_depth=3, n_estimators=50, total=   1.3s
# [CV] max_depth=3, n_estimators=50 ....................................
# [CV] ..................... max_depth=3, n_estimators=50, total=   1.3s
# [CV] max_depth=3, n_estimators=50 ....................................
# [CV] ..................... max_depth=3, n_estimators=50, total=   1.3s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] .................... max_depth=3, n_estimators=100, total=   2.6s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] .................... max_depth=3, n_estimators=100, total=   2.6s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] .................... max_depth=3, n_estimators=100, total=   2.6s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] .................... max_depth=3, n_estimators=100, total=   2.7s
# [CV] max_depth=3, n_estimators=100 ...................................
# [CV] .................... max_depth=3, n_estimators=100, total=   3.0s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] .................... max_depth=3, n_estimators=200, total=   5.4s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] .................... max_depth=3, n_estimators=200, total=   5.2s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] .................... max_depth=3, n_estimators=200, total=   5.5s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] .................... max_depth=3, n_estimators=200, total=   5.3s
# [CV] max_depth=3, n_estimators=200 ...................................
# [CV] .................... max_depth=3, n_estimators=200, total=   5.4s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ..................... max_depth=6, n_estimators=10, total=   0.4s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ..................... max_depth=6, n_estimators=10, total=   0.4s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ..................... max_depth=6, n_estimators=10, total=   0.4s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ..................... max_depth=6, n_estimators=10, total=   0.4s
# [CV] max_depth=6, n_estimators=10 ....................................
# [CV] ..................... max_depth=6, n_estimators=10, total=   0.4s
# [CV] max_depth=6, n_estimators=50 ....................................
# [CV] ..................... max_depth=6, n_estimators=50, total=   2.2s
# [CV] max_depth=6, n_estimators=50 ....................................
# [CV] ..................... max_depth=6, n_estimators=50, total=   2.2s
# [CV] max_depth=6, n_estimators=50 ....................................
# [CV] ..................... max_depth=6, n_estimators=50, total=   2.3s
# [CV] max_depth=6, n_estimators=50 ....................................
# [CV] ..................... max_depth=6, n_estimators=50, total=   2.2s
# [CV] max_depth=6, n_estimators=50 ....................................
# [CV] ..................... max_depth=6, n_estimators=50, total=   2.2s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] .................... max_depth=6, n_estimators=100, total=   4.5s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] .................... max_depth=6, n_estimators=100, total=   4.6s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] .................... max_depth=6, n_estimators=100, total=   4.7s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] .................... max_depth=6, n_estimators=100, total=   4.5s
# [CV] max_depth=6, n_estimators=100 ...................................
# [CV] .................... max_depth=6, n_estimators=100, total=   4.5s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] .................... max_depth=6, n_estimators=200, total=   9.1s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] .................... max_depth=6, n_estimators=200, total=   9.4s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] .................... max_depth=6, n_estimators=200, total=  11.1s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] .................... max_depth=6, n_estimators=200, total=   9.8s
# [CV] max_depth=6, n_estimators=200 ...................................
# [CV] .................... max_depth=6, n_estimators=200, total=   9.6s
# [CV] max_depth=9, n_estimators=10 ....................................
# [CV] ..................... max_depth=9, n_estimators=10, total=   0.7s
# [CV] max_depth=9, n_estimators=10 ....................................
# [CV] ..................... max_depth=9, n_estimators=10, total=   0.6s
# [CV] max_depth=9, n_estimators=10 ....................................
# [CV] ..................... max_depth=9, n_estimators=10, total=   0.6s
# [CV] max_depth=9, n_estimators=10 ....................................
# [CV] ..................... max_depth=9, n_estimators=10, total=   0.7s
# [CV] max_depth=9, n_estimators=10 ....................................
# [CV] ..................... max_depth=9, n_estimators=10, total=   0.8s
# [CV] max_depth=9, n_estimators=50 ....................................
# [CV] ..................... max_depth=9, n_estimators=50, total=   3.3s
# [CV] max_depth=9, n_estimators=50 ....................................
# [CV] ..................... max_depth=9, n_estimators=50, total=   3.5s
# [CV] max_depth=9, n_estimators=50 ....................................
# [CV] ..................... max_depth=9, n_estimators=50, total=   3.5s
# [CV] max_depth=9, n_estimators=50 ....................................
# [CV] ..................... max_depth=9, n_estimators=50, total=   3.3s
# [CV] max_depth=9, n_estimators=50 ....................................
# [CV] ..................... max_depth=9, n_estimators=50, total=   3.5s
# [CV] max_depth=9, n_estimators=100 ...................................
# [CV] .................... max_depth=9, n_estimators=100, total=   7.0s
# [CV] max_depth=9, n_estimators=100 ...................................
# [CV] .................... max_depth=9, n_estimators=100, total=   6.3s
# [CV] max_depth=9, n_estimators=100 ...................................
# [CV] .................... max_depth=9, n_estimators=100, total=   6.4s
# [CV] max_depth=9, n_estimators=100 ...................................
# [CV] .................... max_depth=9, n_estimators=100, total=   6.3s
# [CV] max_depth=9, n_estimators=100 ...................................
# [CV] .................... max_depth=9, n_estimators=100, total=   6.8s
# [CV] max_depth=9, n_estimators=200 ...................................
# [CV] .................... max_depth=9, n_estimators=200, total=  14.3s
# [CV] max_depth=9, n_estimators=200 ...................................
# [CV] .................... max_depth=9, n_estimators=200, total=  18.7s
# [CV] max_depth=9, n_estimators=200 ...................................
# [CV] .................... max_depth=9, n_estimators=200, total=  13.0s
# [CV] max_depth=9, n_estimators=200 ...................................
# [CV] .................... max_depth=9, n_estimators=200, total=  13.5s
# [CV] max_depth=9, n_estimators=200 ...................................
# [CV] .................... max_depth=9, n_estimators=200, total=  13.0s
# [CV] max_depth=12, n_estimators=10 ...................................
# [CV] .................... max_depth=12, n_estimators=10, total=   1.0s
# [CV] max_depth=12, n_estimators=10 ...................................
# [CV] .................... max_depth=12, n_estimators=10, total=   0.9s
# [CV] max_depth=12, n_estimators=10 ...................................
# [CV] .................... max_depth=12, n_estimators=10, total=   0.9s
# [CV] max_depth=12, n_estimators=10 ...................................
# [CV] .................... max_depth=12, n_estimators=10, total=   0.9s
# [CV] max_depth=12, n_estimators=10 ...................................
# [CV] .................... max_depth=12, n_estimators=10, total=   0.9s
# [CV] max_depth=12, n_estimators=50 ...................................
# [CV] .................... max_depth=12, n_estimators=50, total=   4.1s
# [CV] max_depth=12, n_estimators=50 ...................................
# [CV] .................... max_depth=12, n_estimators=50, total=   4.6s
# [CV] max_depth=12, n_estimators=50 ...................................
# [CV] .................... max_depth=12, n_estimators=50, total=   5.1s
# [CV] max_depth=12, n_estimators=50 ...................................
# [CV] .................... max_depth=12, n_estimators=50, total=   4.1s
# [CV] max_depth=12, n_estimators=50 ...................................
# [CV] .................... max_depth=12, n_estimators=50, total=   4.3s
# [CV] max_depth=12, n_estimators=100 ..................................
# [CV] ................... max_depth=12, n_estimators=100, total=   8.4s
# [CV] max_depth=12, n_estimators=100 ..................................
# [CV] ................... max_depth=12, n_estimators=100, total=  11.1s
# [CV] max_depth=12, n_estimators=100 ..................................
# [CV] ................... max_depth=12, n_estimators=100, total=   9.4s
# [CV] max_depth=12, n_estimators=100 ..................................
# [CV] ................... max_depth=12, n_estimators=100, total=   8.3s
# [CV] max_depth=12, n_estimators=100 ..................................
# [CV] ................... max_depth=12, n_estimators=100, total=   8.3s
# [CV] max_depth=12, n_estimators=200 ..................................
# [CV] ................... max_depth=12, n_estimators=200, total=  18.0s
# [CV] max_depth=12, n_estimators=200 ..................................
# [CV] ................... max_depth=12, n_estimators=200, total=  16.1s
# [CV] max_depth=12, n_estimators=200 ..................................
# [CV] ................... max_depth=12, n_estimators=200, total=  17.7s
# [CV] max_depth=12, n_estimators=200 ..................................
# [CV] ................... max_depth=12, n_estimators=200, total=  18.5s
# [CV] max_depth=12, n_estimators=200 ..................................
# [CV] ................... max_depth=12, n_estimators=200, total=  18.4s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  7.0min finished
# GridSearchCV(estimator=RandomForestClassifier(max_depth=3, n_estimators=10,
#                                               random_state=4),
#              param_grid={'max_depth': [3, 6, 9, 12],
#                          'n_estimators': [10, 50, 100, 200]},
#              verbose=2)

# %% [markdown]
# ___________________________________________________________
# **Put the results of the grid search in a pandas DataFrame.**

# %%
gird_cv_results_df = pd.DataFrame(grid_cv.cv_results_)

# %%
gird_cv_results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.323127      0.052402         0.010357        0.003598
# 1        1.366998      0.112789         0.034744        0.001490
# 2        2.624946      0.140998         0.069927        0.008836
# 3        5.225399      0.095290         0.133999        0.012618
# 4        0.428802      0.004613         0.010102        0.001285
# 5        2.158589      0.040295         0.043310        0.000666
# 6        4.462555      0.104971         0.085580        0.004103
# 7        9.597501      0.701333         0.209085        0.036419
# 8        0.674838      0.052902         0.014022        0.001805
# 9        3.327991      0.105187         0.080160        0.026290
# 10       6.440921      0.289492         0.112527        0.004140
# 11      14.253964      2.156767         0.251358        0.037685
# 12       0.867001      0.039930         0.016583        0.002042
# 13       4.358137      0.352455         0.074073        0.005249
# 14       8.956636      1.083296         0.148970        0.014943
# 15      17.460290      0.862805         0.279162        0.016524
#
#    param_max_depth param_n_estimators                                  params  \
# 0                3                 10    {'max_depth': 3, 'n_estimators': 10}
# 1                3                 50    {'max_depth': 3, 'n_estimators': 50}
# 2                3                100   {'max_depth': 3, 'n_estimators': 100}
# 3                3                200   {'max_depth': 3, 'n_estimators': 200}
# 4                6                 10    {'max_depth': 6, 'n_estimators': 10}
# 5                6                 50    {'max_depth': 6, 'n_estimators': 50}
# 6                6                100   {'max_depth': 6, 'n_estimators': 100}
# 7                6                200   {'max_depth': 6, 'n_estimators': 200}
# 8                9                 10    {'max_depth': 9, 'n_estimators': 10}
# 9                9                 50    {'max_depth': 9, 'n_estimators': 50}
# 10               9                100   {'max_depth': 9, 'n_estimators': 100}
# 11               9                200   {'max_depth': 9, 'n_estimators': 200}
# 12              12                 10   {'max_depth': 12, 'n_estimators': 10}
# 13              12                 50   {'max_depth': 12, 'n_estimators': 50}
# 14              12                100  {'max_depth': 12, 'n_estimators': 100}
# 15              12                200  {'max_depth': 12, 'n_estimators': 200}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.814390           0.819269           0.816925
# 1            0.812046           0.815284           0.814346
# 2            0.810640           0.812705           0.813408
# 3            0.811577           0.815518           0.814346
# 4            0.814390           0.818565           0.819972
# 5            0.815561           0.819034           0.819737
# 6            0.815796           0.819972           0.819503
# 7            0.815796           0.819972           0.819269
# 8            0.809702           0.815987           0.819972
# 9            0.815796           0.818565           0.819503
# 10           0.816264           0.819503           0.819737
# 11           0.815327           0.819503           0.819737
# 12           0.816264           0.814112           0.816690
# 13           0.817436           0.817862           0.819737
# 14           0.815796           0.816925           0.820675
# 15           0.816967           0.817862           0.821613
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.824426           0.815284         0.818058        0.003590
# 1            0.820206           0.813408         0.815058        0.002788
# 2            0.820441           0.810830         0.813605        0.003580
# 3            0.821378           0.813408         0.815246        0.003326
# 4            0.826301           0.819503         0.819746        0.003825
# 5            0.826067           0.820206         0.820121        0.003390
# 6            0.827004           0.820206         0.820496        0.003628
# 7            0.826770           0.820675         0.820496        0.003557
# 8            0.824895           0.816221         0.817355        0.005008
# 9            0.826301           0.819972         0.820027        0.003455
# 10           0.826535           0.819269         0.820262        0.003382
# 11           0.827473           0.820675         0.820543        0.003924
# 12           0.825598           0.813408         0.817214        0.004372
# 13           0.827004           0.820441         0.820496        0.003442
# 14           0.828645           0.820441         0.820496        0.004501
# 15           0.828411           0.819034         0.820777        0.004124
#
#     rank_test_score
# 0                11
# 1                15
# 2                16
# 3                14
# 4                10
# 5                 8
# 6                 3
# 7                 3
# 8                12
# 9                 9
# 10                7
# 11                2
# 12               13
# 13                6
# 14                3
# 15                1

# %% [markdown]
# **Find the best hyperparameters from the cross-validation.**

# %%
grid_cv.best_params_
# Out:
# {'max_depth': 12, 'n_estimators': 200}

# %% [markdown]
# ________________________________________________________________________________________________________
# **Create a `pcolormesh` visualization of the mean testing score for each combination of hyperparameters.**
#
# <details>
#     <summary>Hint:</summary>
#     Remember to reshape the values of the mean testing scores to be a two-dimensional 4x4 grid.
# </details>

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,6))
axs[0].plot(gird_cv_results_df['param_n_estimators'],
            gird_cv_results_df['mean_fit_time'],
            '-o')
axs[0].set_xlabel('Number of trees',fontsize=18)
axs[0].set_ylabel('Mean fit time (seconds)',fontsize=18)
axs[1].errorbar(gird_cv_results_df['param_n_estimators'],
                gird_cv_results_df['mean_test_score'],
                yerr=gird_cv_results_df['std_test_score'])
axs[1].set_xlabel('Number of trees',fontsize=18)
axs[1].set_ylabel('Mean testing ROC AUC $\pm$ 1 SD ',fontsize=18)
plt.tight_layout()

# %%
# Create a 5x5 grid
a, b = np.meshgrid(range(5), range(5))

# %%
gsc_res_mean_ts_rs = gird_cv_results_df['mean_test_score'].values.reshape(4, 4)
gsc_res_mean_ts_rs
# Out:
# array([[0.8180584 , 0.81505804, 0.81360475, 0.81524559],
#        [0.81974616, 0.82012116, 0.82049621, 0.82049621],
#        [0.81735538, 0.82002739, 0.82026178, 0.82054312],
#        [0.81721443, 0.82049614, 0.82049621, 0.82077745]])

# %%
# Set color map to `plt.cm.jet`
ax = plt.axes()
pcolor = ax.pcolormesh(a, b, gsc_res_mean_ts_rs, cmap = plt.cm.jet)

# %%
# Visualize pcolormesh
ax = plt.axes()
pcolor = ax.pcolormesh(a, b, gsc_res_mean_ts_rs, cmap = plt.cm.jet)
plt.colorbar(pcolor, label = 'Color scale')
ax.set_xlabel('X coordinate')
ax.set_ylabel('Y coordinate');

# %% [markdown]
# ________________________________________________________________________________________________________
# **Conclude which set of hyperparameters to use.**

# %%
# Create a dataframe of the feature names and importance
feature_imp = pd.DataFrame({'Features': features_response[: -1], 'Importance': grid_cv.best_estimator_.feature_importances_})
feature_imp
# Out:
#      Features  Importance
# 0   LIMIT_BAL    0.059877
# 1   EDUCATION    0.012451
# 2    MARRIAGE    0.007819
# 3         AGE    0.042871
# 4       PAY_1    0.304592
# 5   BILL_AMT1    0.053973
# 6   BILL_AMT2    0.052029
# 7   BILL_AMT3    0.048639
# 8   BILL_AMT4    0.046171
# 9   BILL_AMT5    0.043062
# 10  BILL_AMT6    0.045718
# 11   PAY_AMT1    0.060596
# 12   PAY_AMT2    0.051697
# 13   PAY_AMT3    0.048254
# 14   PAY_AMT4    0.042495
# 15   PAY_AMT5    0.039981
# 16   PAY_AMT6    0.039775

# %%
# Sort values by importance
feature_imp.sort_values(by = 'Importance', ascending = False)
# Out:
#      Features  Importance
# 4       PAY_1    0.304592
# 11   PAY_AMT1    0.060596
# 0   LIMIT_BAL    0.059877
# 5   BILL_AMT1    0.053973
# 6   BILL_AMT2    0.052029
# 12   PAY_AMT2    0.051697
# 7   BILL_AMT3    0.048639
# 13   PAY_AMT3    0.048254
# 8   BILL_AMT4    0.046171
# 10  BILL_AMT6    0.045718
# 9   BILL_AMT5    0.043062
# 3         AGE    0.042871
# 14   PAY_AMT4    0.042495
# 15   PAY_AMT5    0.039981
# 16   PAY_AMT6    0.039775
# 1   EDUCATION    0.012451
# 2    MARRIAGE    0.007819
